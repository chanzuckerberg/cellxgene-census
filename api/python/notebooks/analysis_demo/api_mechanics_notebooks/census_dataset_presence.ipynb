# %% [markdown]
# # Census datasets presence
#
# *Goal:* demonstrate basic use of the `datasets_presence_matrix` array.
#
# The presence matrix is a sparse array, indicating which features (var) were present in each dataset.  The array has dimensions [n_datasets, n_var], and is stored in the SOMA Measurement `varp` collection. The first dimension is indexed by the `soma_joinid` in the `census_datasets` dataframe. The second is indexed by the `soma_joinid` in the `var` dataframe of the measurement.

# %%
import numpy as np
from scipy import sparse
import cell_census

census = cell_census.open_soma()

# Grab the experiment containing human data, and the measurement therein with RNA
human = census["census_data"]["homo_sapiens"]
human_rna = human.ms["RNA"]

# The cell census-wide datasets
datasets_df = census["census_info"]["datasets"].read_as_pandas_all()
datasets_df
# Out:
#      soma_joinid                         collection_id  \
# 0              0  03f821b4-87be-4ff4-b65a-b5fc00061da7
# 1              1  03f821b4-87be-4ff4-b65a-b5fc00061da7
# 2              2  43d4bb39-21af-4d05-b973-4c1fed7b916c
# 3              3  0434a9d4-85fd-4554-b8e3-cf6c582bb2fa
# 4              4  3472f32d-4a33-48e2-aad5-666d4631bf4c
# ..           ...                                   ...
# 454          454  f70ebd97-b3bc-44fe-849d-c18e08fe773d
# 455          455  5d445965-6f1a-4b68-ba3a-b8f765155d3a
# 456          456  5d445965-6f1a-4b68-ba3a-b8f765155d3a
# 457          457  17481d16-ee44-49e5-bcf0-28c0780d8c4a
# 458          458  17481d16-ee44-49e5-bcf0-28c0780d8c4a
#
#                                        collection_name  \
# 0    Local and systemic responses to SARS-CoV-2 inf...
# 1    Local and systemic responses to SARS-CoV-2 inf...
# 2    Transcriptional Programming of Normal and Infl...
# 3    Acute COVID-19 cohort across a range of WHO ca...
# 4    A single-cell transcriptome atlas of the adult...
# ..                                                 ...
# 454  A transcriptomic atlas of the mouse cerebellum...
# 455  A molecular cell atlas of the human lung from ...
# 456  A molecular cell atlas of the human lung from ...
# 457  Single-Cell Sequencing of Developing Human Gut...
# 458  Single-Cell Sequencing of Developing Human Gut...
#
#                    collection_doi                            dataset_id  \
# 0      10.1038/s41586-021-04345-x  edc8d3fe-153c-4e3d-8be0-2108d30f8d70
# 1      10.1038/s41586-021-04345-x  2a498ace-872a-4935-984b-1afa70fd9886
# 2    10.1016/j.celrep.2018.09.006  f512b8b6-369d-4a85-a695-116e0806857f
# 3     10.1101/2020.11.20.20227355  fa8605cf-f27e-44af-ac2a-476bee4410d3
# 4        10.15252/embj.2018100811  d5c67a4e-a8d9-456d-a273-fa01adb1b308
# ..                            ...                                   ...
# 454     10.1101/2020.03.04.976407  e0ed3c55-aff6-4bb7-b6ff-98a2d90b890c
# 455     10.1038/s41586-020-2922-4  e04daea4-4412-45b5-989e-76a9be070a89
# 456     10.1038/s41586-020-2922-4  8c42cfd0-0b0a-46d5-910c-fc833d83c45e
# 457  10.1016/j.devcel.2020.11.010  8e47ed12-c658-4252-b126-381df8d52a3d
# 458  10.1016/j.devcel.2020.11.010  b46237d1-19c6-4af2-9335-9854634bad16
#
#                                       dataset_title  \
# 0                                            Airway
# 1                                              PBMC
# 2                                              Skin
# 3                                             PBMCs
# 4                                            Retina
# ..                                              ...
# 454  A transcriptomic atlas of the mouse cerebellum
# 455   Krasnow Lab Human Lung Cell Atlas, Smart-seq2
# 456          Krasnow Lab Human Lung Cell Atlas, 10X
# 457                    Paediatric Human Gut (4-14y)
# 458                      Fetal Human Gut (6-11 PCW)
#
#                              dataset_h5ad_path  dataset_total_cell_count
# 0    edc8d3fe-153c-4e3d-8be0-2108d30f8d70.h5ad                    236977
# 1    2a498ace-872a-4935-984b-1afa70fd9886.h5ad                    422220
# 2    f512b8b6-369d-4a85-a695-116e0806857f.h5ad                     68036
# 3    fa8605cf-f27e-44af-ac2a-476bee4410d3.h5ad                     59506
# 4    d5c67a4e-a8d9-456d-a273-fa01adb1b308.h5ad                     19694
# ..                                         ...                       ...
# 454  e0ed3c55-aff6-4bb7-b6ff-98a2d90b890c.h5ad                    611034
# 455  e04daea4-4412-45b5-989e-76a9be070a89.h5ad                      9409
# 456  8c42cfd0-0b0a-46d5-910c-fc833d83c45e.h5ad                     65662
# 457  8e47ed12-c658-4252-b126-381df8d52a3d.h5ad                     22502
# 458  b46237d1-19c6-4af2-9335-9854634bad16.h5ad                     62849
#
# [459 rows x 8 columns]

# %% [markdown]
# For convenience, read the entire presence matrix (for Homo sapiens) into a SciPy array. There is a convience API providing this capability, returning the matrix in a scipy.sparse.array:

# %%
presence_matrix = cell_census.get_presence_matrix(census, organism="Homo sapiens", measurement_name="RNA")
presence_matrix
# Out:
# <459x60638 sparse matrix of type '<class 'numpy.uint8'>'
# 	with 12145194 stored elements in Compressed Sparse Row format>

# %% [markdown]
# We also need the `var` dataframe, which is read into a Pandas DataFrame for convenient manipulation:

# %%
var_df = human_rna.var.read_as_pandas_all()

# %% [markdown]
# ## Is a feature present in a dataset?
#
# *Goal:* test if a given feature is present in a given dataset.
#
# **Important:** the presence matrix is indexed by soma_joinid, and is *NOT* positionally indexed.  In other words:
# * the first dimension of the presence matrix is the dataset's `soma_joinid`, as stored in the `census_datasets` dataframe.
# * the second dimension of the presence matrix is the feature's `soma_joinid`, as stored in the `var` dataframe.

# %%
var_joinid = var_df.loc[var_df.feature_id == "ENSG00000286096"].soma_joinid
dataset_joinid = datasets_df.loc[datasets_df.dataset_id == "97a17473-e2b1-4f31-a544-44a60773e2dd"].soma_joinid
is_present = presence_matrix[dataset_joinid, var_joinid][0, 0]
print(f'Feature is {"present" if is_present else "not present"}.')
# Out:
# Feature is present.

# %% [markdown]
# ## What datasets contain a feature?
#
# *Goal:* look up all datasets that have a feature_id present.

# %%
# Grab the feature's soma_joinid from the var dataframe
var_joinid = var_df.loc[var_df.feature_id == "ENSG00000286096"].soma_joinid

# The presence matrix is indexed by the joinids of the dataset and var dataframes,
# so slice out the feature of interest by its joinid.
dataset_joinids = presence_matrix[:, var_joinid].tocoo().row

# From the datasets dataframe, slice out the datasets which have a joinid in the list
datasets_df.loc[datasets_df.soma_joinid.isin(dataset_joinids)]
# Out:
#      soma_joinid                         collection_id  \
# 309  10.1101/2022.10.12.511898  bdb26abd-f4ba-4ea3-8862-c2340e7a4f55
# 319  10.1101/2022.10.12.511898  5e5ab909-f73f-4b57-98a0-6d2c5662f6a4
# 342  10.1101/2022.10.12.511898  35c8a04c-8639-4d15-8228-765d8d93fc96
# 347  10.1101/2022.10.12.511898  3f56901c-dd4a-47d6-b60b-7b0c0111cfb2
# 349  10.1101/2022.10.12.511898  07b1d7c8-5c2e-42f7-9246-26f746cd6013
# 373  10.1101/2022.10.12.511898  7a0a8891-9a22-4549-a55b-c2aca23c3a2a
# 375  10.1101/2022.10.12.511898  7c1c3d47-3166-43e5-9a95-65ceb2d45f78
# 383  10.1101/2022.10.12.511898  93131426-0124-4ab4-a013-9dfbcd99d467
# 384  10.1101/2022.10.12.511898  9372df2d-13d6-4fac-980b-919a5b7eb483
# 396  10.1101/2022.10.12.511898  acae7679-d077-461c-b857-ee6ccfeb267f
# 401  10.1101/2022.10.12.511898  c202b243-1aa1-4b16-bc9a-b36241f3b1e3
# 402  10.1101/2022.10.12.511898  0325478a-9b52-45b5-b40a-2e2ab0d72eb1
# 403  10.1101/2022.10.12.511898  c2aad8fc-b63b-4f9b-9cfd-baf7bc9c1771
# 404  10.1101/2022.10.12.511898  c4b03352-af8d-492a-8d6b-40f304e0a122
# 413  10.1101/2022.10.12.511898  d2b5efc1-14c6-4b5f-bd98-40f9084872d7
# 417  10.1101/2022.10.12.511898  dd03ce70-3243-4c96-9561-330cc461e4d7
# 434  10.1101/2022.10.12.511898  f8dda921-5fb4-4c94-a654-c6fc346bfd6d
# 437  10.1101/2022.10.12.511898  fe1a73ab-a203-45fd-84e9-0f7fd19efcbd
#
#                                          dataset_title  \
# 272                           Tabula Sapiens - Stromal
# 273                        Tabula Sapiens - Epithelial
# 274                            Tabula Sapiens - Immune
# 275                       Tabula Sapiens - Endothelial
# 276                         Tabula Sapiens - All Cells
# 306                                           Splatter
# 309                                    CGE interneuron
# 319  Midbrain (M) - Inferior colliculus and nearby ...
# 342  Hypothalamus (HTH) - supraoptic region of HTH ...
# 347                  Head of hippocampus (HiH) - CA1-3
# 349  Myelencephalon (medulla oblongata) (Mo) - affe...
# 373                                  Hippocampal CA1-3
# 375     Pons (Pn) - Pontine reticular formation - PnRF
# 383                                  Epithalamus - ETH
# 384  Midbrain (M) - Periaqueductal gray and nearby ...
# 396                    Head of hippocampus (HiH) - CA1
# 401                                Amygdala excitatory
# 402                     Upper-layer intratelencephalic
# 403  Cerebral cortex (Cx) - Temporal pole (TP) - Te...
# 404                                Medium spiny neuron
# 413  Tail of Hippocampus (HiT) - Caudal Hippocampus...
# 417  Cerebral cortex (Cx) - Perirhinal gyrus (PRG) ...
# 434  Cerebral cortex (Cx) - Occipitotemporal (fusif...
# 437  Amygdaloid complex (AMY) - basolateral nuclear...
#
#                              dataset_h5ad_path  dataset_total_cell_count
# 272  a68b64d8-aee3-4947-81b7-36b8fe5a44d2.h5ad                     82478
# 273  97a17473-e2b1-4f31-a544-44a60773e2dd.h5ad                    104148
# 274  c5d88abe-f23a-45fa-a534-788985e93dad.h5ad                    264824
# 275  5a11f879-d1ef-458a-910c-9b0bdfca5ebf.h5ad                     31691
# 276  53d208b0-2cfd-4366-9866-c3c6114081bc.h5ad                    483152
# 306  3a7f3ab4-a280-4b3b-b2c0-6dd05614a78c.h5ad                    291833
# 309  bdb26abd-f4ba-4ea3-8862-c2340e7a4f55.h5ad                    227671
# 319  5e5ab909-f73f-4b57-98a0-6d2c5662f6a4.h5ad                     32306
# 342  35c8a04c-8639-4d15-8228-765d8d93fc96.h5ad                     16753
# 347  3f56901c-dd4a-47d6-b60b-7b0c0111cfb2.h5ad                     37911
# 349  07b1d7c8-5c2e-42f7-9246-26f746cd6013.h5ad                     27210
# 373  7a0a8891-9a22-4549-a55b-c2aca23c3a2a.h5ad                     74979
# 375  7c1c3d47-3166-43e5-9a95-65ceb2d45f78.h5ad                     49512
# 383  93131426-0124-4ab4-a013-9dfbcd99d467.h5ad                     24327
# 384  9372df2d-13d6-4fac-980b-919a5b7eb483.h5ad                     33794
# 396  acae7679-d077-461c-b857-ee6ccfeb267f.h5ad                     39147
# 401  c202b243-1aa1-4b16-bc9a-b36241f3b1e3.h5ad                    109452
# 402  0325478a-9b52-45b5-b40a-2e2ab0d72eb1.h5ad                    455006
# 403  c2aad8fc-b63b-4f9b-9cfd-baf7bc9c1771.h5ad                     37642
# 404  c4b03352-af8d-492a-8d6b-40f304e0a122.h5ad                    152189
# 413  d2b5efc1-14c6-4b5f-bd98-40f9084872d7.h5ad                     36886
# 417  dd03ce70-3243-4c96-9561-330cc461e4d7.h5ad                     23732
# 434  f8dda921-5fb4-4c94-a654-c6fc346bfd6d.h5ad                     31899
# 437  fe1a73ab-a203-45fd-84e9-0f7fd19efcbd.h5ad                     35285

# %% [markdown]
# ## What features are in a dataset?
#
# *Goal:* lookup the features present in a given dataset.
#
# This example also demonstrates the ability to do the query on multiple datasets.

# %%
# Slice the dataset(s) of interest, and get the joinid(s)
dataset_joinids = datasets_df.loc[datasets_df.collection_id == "17481d16-ee44-49e5-bcf0-28c0780d8c4a"].soma_joinid

# Slice the presence matrix by the first dimension, i.e., by dataset
var_joinids = presence_matrix[dataset_joinids, :].tocoo().col

# From the feature (var) dataframe, slice out features which have a joinid in the list.
var_df.loc[var_df.soma_joinid.isin(var_joinids)]
# Out:
#        soma_joinid       feature_id      feature_name  feature_length
# 0                0  ENSG00000121410              A1BG            3999
# 1                1  ENSG00000268895          A1BG-AS1            3374
# 2                2  ENSG00000148584              A1CF            9603
# 3                3  ENSG00000175899               A2M            6318
# 4                4  ENSG00000245105           A2M-AS1            2948
# ...            ...              ...               ...             ...
# 44644        44644  ENSG00000219926          OR7E104P            4672
# 44648        44648  ENSG00000267104  TBC1D3P1-DHX40P1            1841
# 44649        44649  ENSG00000265766           CXADRP3            1955
# 44651        44651  ENSG00000267453            CLEC4O             774
# 44654        44654  ENSG00000279274     RP11-533E23.2              75
#
# [27211 rows x 4 columns]
