# %%
import cellxgene_census

census = cellxgene_census.open_soma(census_version="2023-12-15")
adata = cellxgene_census.get_anndata(
    census,
    organism="homo_sapiens",
    measurement_name="RNA",
    obs_value_filter="tissue == 'central nervous system'",
    obsm_layers=["undefined"],
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 4
#       1 import cellxgene_census
#       3 census = cellxgene_census.open_soma(census_version="2023-12-15")
# ----> 4 adata = cellxgene_census.get_anndata(
#       5     census,
#       6     organism = "homo_sapiens",
#       7     measurement_name = "RNA",
#       8     obs_value_filter = "tissue == 'central nervous system'",
#       9     obsm_layers = ["undefined"]
#      10 )
#
# File ~/venv_census/lib/python3.11/site-packages/cellxgene_census/_get_anndata.py:84, in get_anndata(census, organism, measurement_name, X_name, X_layers, obsm_layers, obs_value_filter, obs_coords, var_value_filter, var_coords, column_names)
#      78 var_coords = (slice(None),) if var_coords is None else (var_coords,)
#      79 with exp.axis_query(
#      80     measurement_name,
#      81     obs_query=soma.AxisQuery(value_filter=obs_value_filter, coords=obs_coords),
#      82     var_query=soma.AxisQuery(value_filter=var_value_filter, coords=var_coords),
#      83 ) as query:
# ---> 84     return query.to_anndata(X_name=X_name, column_names=column_names, X_layers=X_layers, obsm_layers=obsm_layers)
#
# File ~/venv_census/lib/python3.11/site-packages/somacore/query/query.py:288, in ExperimentAxisQuery.to_anndata(self, X_name, column_names, X_layers, obsm_layers, obsp_layers, varm_layers, varp_layers)
#     257 def to_anndata(
#     258     self,
#     259     X_name: str,
#    (...)
#     266     varp_layers: Sequence[str] = (),
#     267 ) -> anndata.AnnData:
#     268     """
#     269     Executes the query and return result as an ``AnnData`` in-memory object.
#     270
#    (...)
#     286     Lifecycle: maturing
#     287     """
# --> 288     return self._read(
#     289         X_name,
#     290         column_names=column_names or AxisColumnNames(obs=None, var=None),
#     291         X_layers=X_layers,
#     292         obsm_layers=obsm_layers,
#     293         obsp_layers=obsp_layers,
#     294         varm_layers=varm_layers,
#     295         varp_layers=varp_layers,
#     296     ).to_anndata()
#
# File ~/venv_census/lib/python3.11/site-packages/somacore/query/query.py:414, in ExperimentAxisQuery._read(self, X_name, column_names, X_layers, obsm_layers, obsp_layers, varm_layers, varp_layers)
#     407 var = var_table.to_pandas()
#     408 var.index = var.index.astype(str)
#     410 return _AxisQueryResult(
#     411     obs=obs,
#     412     var=var,
#     413     X=x,
# --> 414     obsm=obsm_ft.result(),
#     415     obsp=obsp_ft.result(),
#     416     varm=varm_ft.result(),
#     417     varp=varp_ft.result(),
#     418     X_layers=x_matrices,
#     419 )
#
# File /usr/local/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/local/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /usr/local/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/venv_census/lib/python3.11/site-packages/somacore/query/query.py:378, in ExperimentAxisQuery._read.<locals>._read_axis_mappings(fn, axis, keys)
#     377 def _read_axis_mappings(fn, axis, keys: Sequence[str]) -> Dict[str, np.ndarray]:
# --> 378     return {key: fn(axis, key) for key in keys}
#
# File ~/venv_census/lib/python3.11/site-packages/somacore/query/query.py:378, in <dictcomp>(.0)
#     377 def _read_axis_mappings(fn, axis, keys: Sequence[str]) -> Dict[str, np.ndarray]:
# --> 378     return {key: fn(axis, key) for key in keys}
#
# File ~/venv_census/lib/python3.11/site-packages/somacore/query/query.py:561, in ExperimentAxisQuery._axism_inner_ndarray(self, axis, layer)
#     554 def _axism_inner_ndarray(
#     555     self,
#     556     axis: "_Axis",
#     557     layer: str,
#     558 ) -> np.ndarray:
#     559     axism = axis.getitem_from(self._ms, suf="m")
# --> 561     _, n_col = axism[layer].shape
#     562     n_row = len(axis.getattr_from(self._joinids))
#     564     table = self._axism_inner(axis, layer).tables().concat()
#
# File ~/venv_census/lib/python3.11/site-packages/tiledbsoma/_collection.py:425, in CollectionBase.__getitem__(self, key)
#     423     entry = self._contents[key]
#     424 except KeyError:
# --> 425     raise KeyError(err_str) from None
#     426 if entry.soma is None:
#     427     from . import _factory  # Delayed binding to resolve circular import.
#
# KeyError: "Collection has no item 'undefined'"
