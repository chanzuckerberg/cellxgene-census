# %% [markdown]
# # Genes measured in each cell (dataset presence matrix)
#
# The Census is a compilation of cells from multiple datasets that may differ by the sets of genes they measure. This notebook describes the way to identify the genes measured per dataset.
#
# The presence matrix is a sparse boolean array, indicating which features (var) were present in each dataset.  The array has dimensions [n_datasets, n_var], and is stored in the SOMA Measurement `varp` collection. The first dimension is indexed by the `soma_joinid` in the `census_datasets` dataframe. The second is indexed by the `soma_joinid` in the `var` dataframe of the measurement.
#
# As a reminder the `obs` data frame has a column `dataset_id` that can be used to link any cell in the Census to the presence matrix.
#
# **Contents**
#
# 1. Opening the Census.
# 2. Fetching the IDs of the Census datasets.
# 3. Fetching the dataset presence matrix.
# 4. Identifying genes measured in a specific dataset.
# 5. Identifying datasets that measured specific genes.
# 6. Identifying all genes measured in a dataset.
#
#
# ## Opening the Census
#
# The `cellxgene_census` python package contains a convenient API to open the latest version of the Census.

# %%
import numpy as np
from scipy import sparse
import cellxgene_census

census = cellxgene_census.open_soma()

# %% [markdown]
# ## Fetching the IDs of the Census datasets
#
# Let's grab a table of all the datasets included in the Census and use this table in combination with the presence matrix below.

# %%
# Grab the experiment containing human data, and the measurement therein with RNA
human = census["census_data"]["homo_sapiens"]
human_rna = human.ms["RNA"]

# The census-wide datasets
datasets_df = census["census_info"]["datasets"].read().concat().to_pandas()

datasets_df
# Out:
#      soma_joinid                         collection_id
# 0              0  43d4bb39-21af-4d05-b973-4c1fed7b916c  \
# 1              1  2b02dff7-e427-4cdc-96fb-c0f354c099aa
# 2              2  e9eec7f5-8519-42f6-99b4-6dbd9cc5ef03
# 3              3  a72afd53-ab92-4511-88da-252fb0e26b9a
# 4              4  e4c9ed14-e560-4900-a3bf-b0f8d2ce6a10
# ..           ...                                   ...
# 524          524  e3f391f6-5a75-4e96-8450-da47c3d2a939
# 525          525  e3f391f6-5a75-4e96-8450-da47c3d2a939
# 526          526  e3f391f6-5a75-4e96-8450-da47c3d2a939
# 527          527  e3f391f6-5a75-4e96-8450-da47c3d2a939
# 528          528  e3f391f6-5a75-4e96-8450-da47c3d2a939
#
#                                        collection_name
# 0    Transcriptional Programming of Normal and Infl...  \
# 1    Single-Cell Analysis of Crohn’s Disease Lesion...
# 2    Humoral immunity at the brain borders in homeo...
# 3    Single-cell atlas of peripheral immune respons...
# 4    A molecular single-cell lung atlas of lethal C...
# ..                                                 ...
# 524  COVID-19 mRNA vaccine elicits a potent adaptiv...
# 525  COVID-19 mRNA vaccine elicits a potent adaptiv...
# 526  COVID-19 mRNA vaccine elicits a potent adaptiv...
# 527  COVID-19 mRNA vaccine elicits a potent adaptiv...
# 528  COVID-19 mRNA vaccine elicits a potent adaptiv...
#
#                    collection_doi                            dataset_id
# 0    10.1016/j.celrep.2018.09.006  f512b8b6-369d-4a85-a695-116e0806857f  \
# 1      10.1016/j.cell.2019.08.008  36c867a7-be10-4e69-9b39-5de12b0af6da
# 2       10.1016/j.coi.2022.102188  58b01044-c5e5-4b0f-8a2d-6ebf951e01ff
# 3       10.1038/s41591-020-0944-y  456e8b9b-f872-488b-871d-94534090a865
# 4      10.1038/s41586-021-03569-1  d8da613f-e681-4c69-b463-e94f5e66847f
# ..                            ...                                   ...
# 524                                30498543-4fdd-4f86-9e1b-05c1a1454a6a
# 525                                b5191f01-f67d-44b8-bc8d-511a4ecd07bb
# 526                                e463dae9-3fc1-476d-870e-d98a04c56cd6
# 527                                1b699e04-1127-42ea-998b-011ace4a5b81
# 528                                87ce26ed-e5d1-44b4-81cc-cc5b709a169f
#
#                                          dataset_title
# 0                                                 Skin  \
# 1                                                Ileum
# 2    A scRNA-seq atlas of immune cells at the CNS b...
# 3    Single-cell atlas of peripheral immune respons...
# 4    A molecular single-cell lung atlas of lethal C...
# ..                                                 ...
# 524      B cells -- CV19 infection, vaccination and HC
# 525  innate T cells -- CV19 infection, vaccination ...
# 526      M cells -- CV19 infection, vaccination and HC
# 527      T cells -- CV19 infection, vaccination and HC
# 528  Circulating Immune cells -- CV19 infection, va...
#
#                              dataset_h5ad_path  dataset_total_cell_count
# 0    f512b8b6-369d-4a85-a695-116e0806857f.h5ad                     68036
# 1    36c867a7-be10-4e69-9b39-5de12b0af6da.h5ad                     32458
# 2    58b01044-c5e5-4b0f-8a2d-6ebf951e01ff.h5ad                    130908
# 3    456e8b9b-f872-488b-871d-94534090a865.h5ad                     44721
# 4    d8da613f-e681-4c69-b463-e94f5e66847f.h5ad                    116313
# ..                                         ...                       ...
# 524  30498543-4fdd-4f86-9e1b-05c1a1454a6a.h5ad                     20727
# 525  b5191f01-f67d-44b8-bc8d-511a4ecd07bb.h5ad                     33415
# 526  e463dae9-3fc1-476d-870e-d98a04c56cd6.h5ad                     41130
# 527  1b699e04-1127-42ea-998b-011ace4a5b81.h5ad                     98068
# 528  87ce26ed-e5d1-44b4-81cc-cc5b709a169f.h5ad                    195632
#
# [529 rows x 8 columns]

# %% [markdown]
# ## Fetching the dataset presence matrix
#
# Now let's fetch the dataset presence matrix.
#
# For convenience, read the entire presence matrix (for Homo sapiens) into a SciPy array. There is a convenience API providing this capability, returning the matrix in a `scipy.sparse.array`.

# %%
presence_matrix = cellxgene_census.get_presence_matrix(
    census, organism="Homo sapiens", measurement_name="RNA"
)

presence_matrix
# Out:
# <529x60664 sparse matrix of type '<class 'numpy.uint8'>'
# 	with 14006372 stored elements in Compressed Sparse Row format>

# %% [markdown]
# We also need the `var` dataframe, which is read into a Pandas DataFrame for convenient manipulation:

# %%
var_df = human_rna.var.read().concat().to_pandas()

var_df
# Out:
#        soma_joinid       feature_id    feature_name  feature_length
# 0                0  ENSG00000238009    RP11-34P13.7            3726
# 1                1  ENSG00000279457          WASH9P            1397
# 2                2  ENSG00000228463      AP006222.1            8224
# 3                3  ENSG00000237094    RP4-669L17.4            6204
# 4                4  ENSG00000230021  RP11-206L10.17            5495
# ...            ...              ...             ...             ...
# 60659        60659  ENSG00000288719   RP4-669P10.21            4252
# 60660        60660  ENSG00000288720   RP11-852E15.3            7007
# 60661        60661  ENSG00000288721    RP5-973N23.5            7765
# 60662        60662  ENSG00000288723   RP11-553N16.6            1015
# 60663        60663  ENSG00000288724    RP13-546I2.2             625
#
# [60664 rows x 4 columns]

# %% [markdown]
# ## Identifying genes measured in a specific dataset.
#
# Now that we have the dataset table, the genes metadata table, and the dataset presence matrix, we can check if a gene or set of genes were measured in a specific dataset.
#
# **Important:** the presence matrix is indexed by soma_joinid, and is *NOT* positionally indexed.  In other words:
# * the first dimension of the presence matrix is the dataset's `soma_joinid`, as stored in the `census_datasets` dataframe.
# * the second dimension of the presence matrix is the feature's `soma_joinid`, as stored in the `var` dataframe.
#
# Let's find out if the the gene `"ENSG00000286096"` was measured in the dataset with id `"97a17473-e2b1-4f31-a544-44a60773e2dd"`.

# %%
var_joinid = var_df.loc[var_df.feature_id == "ENSG00000286096"].soma_joinid
dataset_joinid = datasets_df.loc[
    datasets_df.dataset_id == "97a17473-e2b1-4f31-a544-44a60773e2dd"
].soma_joinid
is_present = presence_matrix[dataset_joinid, var_joinid][0, 0]
print(f'Feature is {"present" if is_present else "not present"}.')
# Out:
# Feature is present.

# %% [markdown]
# ## Identifying datasets that measured specific genes
#
# Similarly, we can determine the datasets that measured a specific gene or set of genes.

# %%
# Grab the feature's soma_joinid from the var dataframe
var_joinid = var_df.loc[var_df.feature_id == "ENSG00000286096"].soma_joinid

# The presence matrix is indexed by the joinids of the dataset and var dataframes,
# so slice out the feature of interest by its joinid.
dataset_joinids = presence_matrix[:, var_joinid].tocoo().row

# From the datasets dataframe, slice out the datasets which have a joinid in the list
datasets_df.loc[datasets_df.soma_joinid.isin(dataset_joinids)]
# Out:
#      soma_joinid                         collection_id
# 335          335  e5f58829-1a66-40b5-a624-9046778e74f5  \
# 336          336  e5f58829-1a66-40b5-a624-9046778e74f5
# 337          337  e5f58829-1a66-40b5-a624-9046778e74f5
# 338          338  e5f58829-1a66-40b5-a624-9046778e74f5
# 339          339  e5f58829-1a66-40b5-a624-9046778e74f5
# 358          358  283d65eb-dd53-496d-adb7-7570c7caa443
# 371          371  283d65eb-dd53-496d-adb7-7570c7caa443
# 372          372  283d65eb-dd53-496d-adb7-7570c7caa443
# 399          399  283d65eb-dd53-496d-adb7-7570c7caa443
# 413          413  283d65eb-dd53-496d-adb7-7570c7caa443
# 415          415  283d65eb-dd53-496d-adb7-7570c7caa443
# 419          419  283d65eb-dd53-496d-adb7-7570c7caa443
# 422          422  283d65eb-dd53-496d-adb7-7570c7caa443
# 424          424  283d65eb-dd53-496d-adb7-7570c7caa443
# 426          426  283d65eb-dd53-496d-adb7-7570c7caa443
# 434          434  283d65eb-dd53-496d-adb7-7570c7caa443
# 436          436  283d65eb-dd53-496d-adb7-7570c7caa443
# 452          452  283d65eb-dd53-496d-adb7-7570c7caa443
# 458          458  283d65eb-dd53-496d-adb7-7570c7caa443
# 460          460  283d65eb-dd53-496d-adb7-7570c7caa443
# 462          462  283d65eb-dd53-496d-adb7-7570c7caa443
# 464          464  283d65eb-dd53-496d-adb7-7570c7caa443
# 465          465  283d65eb-dd53-496d-adb7-7570c7caa443
# 482          482  283d65eb-dd53-496d-adb7-7570c7caa443
#
#                                        collection_name
# 335                                     Tabula Sapiens  \
# 336                                     Tabula Sapiens
# 337                                     Tabula Sapiens
# 338                                     Tabula Sapiens
# 339                                     Tabula Sapiens
# 358  Transcriptomic diversity of cell types across ...
# 371  Transcriptomic diversity of cell types across ...
# 372  Transcriptomic diversity of cell types across ...
# 399  Transcriptomic diversity of cell types across ...
# 413  Transcriptomic diversity of cell types across ...
# 415  Transcriptomic diversity of cell types across ...
# 419  Transcriptomic diversity of cell types across ...
# 422  Transcriptomic diversity of cell types across ...
# 424  Transcriptomic diversity of cell types across ...
# 426  Transcriptomic diversity of cell types across ...
# 434  Transcriptomic diversity of cell types across ...
# 436  Transcriptomic diversity of cell types across ...
# 452  Transcriptomic diversity of cell types across ...
# 458  Transcriptomic diversity of cell types across ...
# 460  Transcriptomic diversity of cell types across ...
# 462  Transcriptomic diversity of cell types across ...
# 464  Transcriptomic diversity of cell types across ...
# 465  Transcriptomic diversity of cell types across ...
# 482  Transcriptomic diversity of cell types across ...
#
#                 collection_doi                            dataset_id
# 335    10.1126/science.abl4896  a68b64d8-aee3-4947-81b7-36b8fe5a44d2  \
# 336    10.1126/science.abl4896  97a17473-e2b1-4f31-a544-44a60773e2dd
# 337    10.1126/science.abl4896  c5d88abe-f23a-45fa-a534-788985e93dad
# 338    10.1126/science.abl4896  5a11f879-d1ef-458a-910c-9b0bdfca5ebf
# 339    10.1126/science.abl4896  53d208b0-2cfd-4366-9866-c3c6114081bc
# 358  10.1101/2022.10.12.511898  07b1d7c8-5c2e-42f7-9246-26f746cd6013
# 371  10.1101/2022.10.12.511898  7c1c3d47-3166-43e5-9a95-65ceb2d45f78
# 372  10.1101/2022.10.12.511898  9372df2d-13d6-4fac-980b-919a5b7eb483
# 399  10.1101/2022.10.12.511898  dd03ce70-3243-4c96-9561-330cc461e4d7
# 413  10.1101/2022.10.12.511898  7a0a8891-9a22-4549-a55b-c2aca23c3a2a
# 415  10.1101/2022.10.12.511898  d2b5efc1-14c6-4b5f-bd98-40f9084872d7
# 419  10.1101/2022.10.12.511898  f8dda921-5fb4-4c94-a654-c6fc346bfd6d
# 422  10.1101/2022.10.12.511898  3a7f3ab4-a280-4b3b-b2c0-6dd05614a78c
# 424  10.1101/2022.10.12.511898  bdb26abd-f4ba-4ea3-8862-c2340e7a4f55
# 426  10.1101/2022.10.12.511898  5e5ab909-f73f-4b57-98a0-6d2c5662f6a4
# 434  10.1101/2022.10.12.511898  35c8a04c-8639-4d15-8228-765d8d93fc96
# 436  10.1101/2022.10.12.511898  3f56901c-dd4a-47d6-b60b-7b0c0111cfb2
# 452  10.1101/2022.10.12.511898  93131426-0124-4ab4-a013-9dfbcd99d467
# 458  10.1101/2022.10.12.511898  acae7679-d077-461c-b857-ee6ccfeb267f
# 460  10.1101/2022.10.12.511898  c202b243-1aa1-4b16-bc9a-b36241f3b1e3
# 462  10.1101/2022.10.12.511898  0325478a-9b52-45b5-b40a-2e2ab0d72eb1
# 464  10.1101/2022.10.12.511898  c2aad8fc-b63b-4f9b-9cfd-baf7bc9c1771
# 465  10.1101/2022.10.12.511898  c4b03352-af8d-492a-8d6b-40f304e0a122
# 482  10.1101/2022.10.12.511898  fe1a73ab-a203-45fd-84e9-0f7fd19efcbd
#
#                                          dataset_title
# 335                           Tabula Sapiens - Stromal  \
# 336                        Tabula Sapiens - Epithelial
# 337                            Tabula Sapiens - Immune
# 338                       Tabula Sapiens - Endothelial
# 339                         Tabula Sapiens - All Cells
# 358  Dissection: Myelencephalon (medulla oblongata)...
# 371  Dissection: Pons (Pn) - Pontine reticular form...
# 372  Dissection: Midbrain (M) - Periaqueductal gray...
# 399  Dissection: Cerebral cortex (Cx) - Perirhinal ...
# 413                    Supercluster: Hippocampal CA1-3
# 415  Dissection: Tail of Hippocampus (HiT) - Caudal...
# 419  Dissection: Cerebral cortex (Cx) - Occipitotem...
# 422                             Supercluster: Splatter
# 424                      Supercluster: CGE interneuron
# 426  Dissection: Midbrain (M) - Inferior colliculus...
# 434  Dissection: Hypothalamus (HTH) - supraoptic re...
# 436      Dissection: Head of hippocampus (HiH) - CA1-3
# 452                      Dissection: Epithalamus - ETH
# 458        Dissection: Head of hippocampus (HiH) - CA1
# 460                  Supercluster: Amygdala excitatory
# 462       Supercluster: Upper-layer intratelencephalic
# 464  Dissection: Cerebral cortex (Cx) - Temporal po...
# 465                  Supercluster: Medium spiny neuron
# 482  Dissection: Amygdaloid complex (AMY) - basolat...
#
#                              dataset_h5ad_path  dataset_total_cell_count
# 335  a68b64d8-aee3-4947-81b7-36b8fe5a44d2.h5ad                     82478
# 336  97a17473-e2b1-4f31-a544-44a60773e2dd.h5ad                    104148
# 337  c5d88abe-f23a-45fa-a534-788985e93dad.h5ad                    264824
# 338  5a11f879-d1ef-458a-910c-9b0bdfca5ebf.h5ad                     31691
# 339  53d208b0-2cfd-4366-9866-c3c6114081bc.h5ad                    483152
# 358  07b1d7c8-5c2e-42f7-9246-26f746cd6013.h5ad                     27210
# 371  7c1c3d47-3166-43e5-9a95-65ceb2d45f78.h5ad                     49512
# 372  9372df2d-13d6-4fac-980b-919a5b7eb483.h5ad                     33794
# 399  dd03ce70-3243-4c96-9561-330cc461e4d7.h5ad                     23732
# 413  7a0a8891-9a22-4549-a55b-c2aca23c3a2a.h5ad                     74979
# 415  d2b5efc1-14c6-4b5f-bd98-40f9084872d7.h5ad                     36886
# 419  f8dda921-5fb4-4c94-a654-c6fc346bfd6d.h5ad                     31899
# 422  3a7f3ab4-a280-4b3b-b2c0-6dd05614a78c.h5ad                    291833
# 424  bdb26abd-f4ba-4ea3-8862-c2340e7a4f55.h5ad                    227671
# 426  5e5ab909-f73f-4b57-98a0-6d2c5662f6a4.h5ad                     32306
# 434  35c8a04c-8639-4d15-8228-765d8d93fc96.h5ad                     16753
# 436  3f56901c-dd4a-47d6-b60b-7b0c0111cfb2.h5ad                     37911
# 452  93131426-0124-4ab4-a013-9dfbcd99d467.h5ad                     24327
# 458  acae7679-d077-461c-b857-ee6ccfeb267f.h5ad                     39147
# 460  c202b243-1aa1-4b16-bc9a-b36241f3b1e3.h5ad                    109452
# 462  0325478a-9b52-45b5-b40a-2e2ab0d72eb1.h5ad                    455006
# 464  c2aad8fc-b63b-4f9b-9cfd-baf7bc9c1771.h5ad                     37642
# 465  c4b03352-af8d-492a-8d6b-40f304e0a122.h5ad                    152189
# 482  fe1a73ab-a203-45fd-84e9-0f7fd19efcbd.h5ad                     35285

# %% [markdown]
# ## Identifying all genes measured in a dataset
#
# Finally, we can find the set of genes that were measured in the cells of a given dataset.

# %%
# Slice the dataset(s) of interest, and get the joinid(s)
dataset_joinids = datasets_df.loc[
    datasets_df.collection_id == "17481d16-ee44-49e5-bcf0-28c0780d8c4a"
].soma_joinid

# Slice the presence matrix by the first dimension, i.e., by dataset
var_joinids = presence_matrix[dataset_joinids, :].tocoo().col

# From the feature (var) dataframe, slice out features which have a joinid in the list.
var_df.loc[var_df.soma_joinid.isin(var_joinids)]
# Out:
#        soma_joinid       feature_id    feature_name  feature_length
# 0                0  ENSG00000238009    RP11-34P13.7            3726
# 1                1  ENSG00000279457          WASH9P            1397
# 2                2  ENSG00000228463      AP006222.1            8224
# 3                3  ENSG00000237094    RP4-669L17.4            6204
# 4                4  ENSG00000230021  RP11-206L10.17            5495
# ...            ...              ...             ...             ...
# 40210        40210  ENSG00000255669    RP11-885B4.2            1023
# 40219        40219  ENSG00000255618       LINC02440             741
# 40352        40352  ENSG00000261627     RP11-91I8.1             508
# 40367        40367  ENSG00000233376    RP5-881L22.6             403
# 40376        40376  ENSG00000267465      AC011525.4            3363
#
# [27211 rows x 4 columns]
