# %%
import cellxgene_census
import tiledbsoma as soma
import pandas as pd
import numpy as np

from scipy.sparse import csr_matrix

# %% [markdown]
# ## QC results
#
# Light QC on test build shows no issues
#
# Checks
#
# ✅ High-level data is accesible and looks in order for `census["census_info"]` and `census["census_data"]`
#
# ✅ Expected increase in cells from latest LTS 154M to 211M
#
# ✅ Similar expected increase in other categories (datasets, donors, unique cells)
#
# ❌ Duplicated rows for `homo_sapiens` and `mus_musculus` in `census_new["census_info"]["organisms"]`
#
# ✅ All assays increased in N cells, no decreases
#
# ✅ Normalized layer was properly created
#
# ✅ Normalized layer was properly created for full-gene sequencing asssays
#
# ✅ Spot checking obs and var contents across all organisms shows compliance with Discover schema 7.0.0
#
# ✅ Spot checking expression matrices across all organisms shows expected values
#
# ✅ Anndata exporting works for all organisms

# %%
DEFAULT_TILEDB_CONFIGURATION = {
    # https://docs.tiledb.com/main/how-to/configuration#configuration-parameters
    "py.init_buffer_bytes": 1 * 1024**3,
    "soma.init_buffer_bytes": 1 * 1024**3,
    # S3 requests should not be signed, since we want to allow anonymous access
    "vfs.s3.no_sign_request": "false",
    "vfs.s3.region": "us-west-2",
}
ctx = soma.options.SOMATileDBContext().replace(tiledb_config=DEFAULT_TILEDB_CONFIGURATION)
census_old = cellxgene_census.open_soma(census_version="2025-01-30")
census_new = cellxgene_census.open_soma(uri="s3://cellxgene-census-dev/cell-census/2025-10-27/soma", context=ctx)

# %% [markdown]
# ## Checking census["info"]

# %%
census_old["census_info"]["summary"].read().concat().to_pandas()
# Out:
#    soma_joinid                       label  \
# 0            0       census_schema_version
# 1            1           census_build_date
# 2            2      dataset_schema_version
# 3            3            total_cell_count
# 4            4           unique_cell_count
# 5            5  number_donors_homo_sapiens
# 6            6  number_donors_mus_musculus
#
#                                         value
# 0                                       2.1.0
# 1  spatial-build-rc3-io2-2025-01-30T21:20:53Z
# 2                                       5.2.0
# 3                                   154437194
# 4                                    85809959
# 5                                         390
# 6                                         172

# %%
census_new["census_info"]["summary"].read().concat().to_pandas()
# Out:
#    soma_joinid                   label       value
# 0            0   census_schema_version       2.4.0
# 1            1       census_build_date  2025-10-27
# 2            2  dataset_schema_version       7.0.0
# 3            3        total_cell_count   211913318
# 4            4       unique_cell_count   124710875

# %%
census_new["census_info"]["organisms"].read().concat().to_pandas()
# Out:
#    soma_joinid organism_ontology_term_id      organism_label  \
# 0            0            NCBITaxon:9606        Homo sapiens
# 1            1           NCBITaxon:10090        Mus musculus
# 2            2            NCBITaxon:9606        Homo sapiens
# 3            3           NCBITaxon:10090        Mus musculus
# 4            4            NCBITaxon:9483  Callithrix jacchus
# 5            5            NCBITaxon:9544      Macaca mulatta
# 6            6            NCBITaxon:9598     Pan troglodytes
#
#              organism
# 0        homo_sapiens
# 1        mus_musculus
# 2        homo_sapiens
# 3        mus_musculus
# 4  callithrix_jacchus
# 5      macaca_mulatta
# 6     pan_troglodytes

# %%
census_old["census_info"]["datasets"].read().concat().to_pandas()
# Out:
#       soma_joinid                                           citation  \
# 0               0  Publication: https://doi.org/10.1016/j.isci.20...
# 1               1  Publication: https://doi.org/10.1016/j.isci.20...
# 2               2  Publication: https://doi.org/10.1016/j.isci.20...
# 3               3  Publication: https://doi.org/10.1016/j.isci.20...
# 4               4  Publication: https://doi.org/10.1038/s41591-02...
# ...           ...                                                ...
# 1568         1568  Publication: https://doi.org/10.1038/s41586-02...
# 1569         1569  Publication: https://doi.org/10.1126/science.a...
# 1570         1570  Publication: https://doi.org/10.1038/s41586-02...
# 1571         1571  Publication: https://doi.org/10.1038/s41593-02...
# 1572         1572  Publication: https://doi.org/10.1038/s41593-02...
#
#                              collection_id  \
# 0     8e880741-bf9a-4c8e-9227-934204631d2a
# 1     8e880741-bf9a-4c8e-9227-934204631d2a
# 2     8e880741-bf9a-4c8e-9227-934204631d2a
# 3     8e880741-bf9a-4c8e-9227-934204631d2a
# 4     a96133de-e951-4e2d-ace6-59db8b3bfb1d
# ...                                    ...
# 1568  45d5d2c3-bc28-4814-aed6-0bb6f0e11c82
# 1569  e5f58829-1a66-40b5-a624-9046778e74f5
# 1570  45d5d2c3-bc28-4814-aed6-0bb6f0e11c82
# 1571  1ca90a2d-2943-483d-b678-b809bf464c30
# 1572  1ca90a2d-2943-483d-b678-b809bf464c30
#
#                                         collection_name  \
# 0     High Resolution Slide-seqV2 Spatial Transcript...
# 1     High Resolution Slide-seqV2 Spatial Transcript...
# 2     High Resolution Slide-seqV2 Spatial Transcript...
# 3     High Resolution Slide-seqV2 Spatial Transcript...
# 4     HTAN/HTAPP Broad - Spatio-molecular dissection...
# ...                                                 ...
# 1568  A single-cell transcriptional timelapse of mou...
# 1569                                     Tabula Sapiens
# 1570  A single-cell transcriptional timelapse of mou...
# 1571  SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
# 1572  SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
#
#                   collection_doi  \
# 0     10.1016/j.isci.2022.104097
# 1     10.1016/j.isci.2022.104097
# 2     10.1016/j.isci.2022.104097
# 3     10.1016/j.isci.2022.104097
# 4     10.1038/s41591-024-03215-z
# ...                          ...
# 1568  10.1038/s41586-024-07069-w
# 1569     10.1126/science.abl4896
# 1570  10.1038/s41586-024-07069-w
# 1571  10.1038/s41593-024-01774-5
# 1572  10.1038/s41593-024-01774-5
#
#                                    collection_doi_label  \
# 0                       Marshall et al. (2022) iScience
# 1                       Marshall et al. (2022) iScience
# 2                       Marshall et al. (2022) iScience
# 3                       Marshall et al. (2022) iScience
# 4                      Klughammer et al. (2024) Nat Med
# ...                                                 ...
# 1568                           Qiu et al. (2024) Nature
# 1569  The Tabula Sapiens Consortium* et al. (2022) S...
# 1570                           Qiu et al. (2024) Nature
# 1571                 Gabitto et al. (2024) Nat Neurosci
# 1572                 Gabitto et al. (2024) Nat Neurosci
#
#                                 dataset_id  \
# 0     4eb29386-de81-452f-b3c0-e00844e8c7fd
# 1     78d59e4a-82eb-4a61-a1dc-da974d7ea54b
# 2     add5eb84-5fc9-4f01-982e-a346dd42ee82
# 3     b020294c-ab82-4547-b5a7-63d8ffa575ed
# 4     d7476ae2-e320-4703-8304-da5c42627e71
# ...                                    ...
# 1568  dcfa2614-7ca7-4d82-814c-350626eccb26
# 1569  53d208b0-2cfd-4366-9866-c3c6114081bc
# 1570  dcfd4feb-18a3-4b30-81d7-1b0c544a8ab3
# 1571  c2876b1b-06d8-4d96-a56b-5304f815b99a
# 1572  6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
#
#                         dataset_version_id  \
# 0     f76861bb-becb-4eb7-82fc-782dc96ccc7f
# 1     7d7ec1b6-6e3f-4aaa-9442-4b22f3424396
# 2     de54aed8-4f73-48f6-9229-418a840e2d82
# 3     abe4fce1-0859-4a56-ad1e-734d79f0e6c8
# 4     863fc5e4-bd4a-4681-9c3d-0ee7ef54e327
# ...                                    ...
# 1568  3002a659-a1a9-4406-9976-99e658e1fbb5
# 1569  10df7690-6d10-4029-a47e-0f071bb2df83
# 1570  3817734b-0f82-433b-8c38-55b214200fff
# 1571  c32964d2-3339-441f-8e56-7177234c7876
# 1572  d3427e8c-c55d-4d4e-b15b-1a8774cd3a4b
#
#                                           dataset_title  \
# 0      Spatial transcriptomics in mouse: Puck_191112_05
# 1      Spatial transcriptomics in mouse: Puck_191112_08
# 2      Spatial transcriptomics in mouse: Puck_191109_20
# 3      Spatial transcriptomics in mouse: Puck_191112_13
# 4                          HTAPP-330-SMP-1082 scRNA-seq
# ...                                                 ...
# 1568                       Major cell cluster: Mesoderm
# 1569                         Tabula Sapiens - All Cells
# 1570                     Whole dataset: Raw counts only
# 1571  Whole Taxonomy - MTG: Seattle Alzheimer's Dise...
# 1572  Whole Taxonomy - DLPFC: Seattle Alzheimer's Di...
#
#                               dataset_h5ad_path  dataset_total_cell_count
# 0     4eb29386-de81-452f-b3c0-e00844e8c7fd.h5ad                     10888
# 1     78d59e4a-82eb-4a61-a1dc-da974d7ea54b.h5ad                     10250
# 2     add5eb84-5fc9-4f01-982e-a346dd42ee82.h5ad                     12906
# 3     b020294c-ab82-4547-b5a7-63d8ffa575ed.h5ad                     15161
# 4     d7476ae2-e320-4703-8304-da5c42627e71.h5ad                       565
# ...                                         ...                       ...
# 1568  dcfa2614-7ca7-4d82-814c-350626eccb26.h5ad                   3267338
# 1569  53d208b0-2cfd-4366-9866-c3c6114081bc.h5ad                   1136218
# 1570  dcfd4feb-18a3-4b30-81d7-1b0c544a8ab3.h5ad                  11441407
# 1571  c2876b1b-06d8-4d96-a56b-5304f815b99a.h5ad                   1226855
# 1572  6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3.h5ad                   1309414
#
# [1573 rows x 11 columns]

# %%
census_new["census_info"]["datasets"].read().concat().to_pandas()
# Out:
#       soma_joinid                                           citation  \
# 0               0  Publication: https://doi.org/10.1016/j.isci.20...
# 1               1  Publication: https://doi.org/10.1016/j.isci.20...
# 2               2  Publication: https://doi.org/10.1016/j.isci.20...
# 3               3  Publication: https://doi.org/10.1016/j.isci.20...
# 4               4  Publication: https://doi.org/10.1038/s41591-02...
# ...           ...                                                ...
# 1810         1810  Publication: https://doi.org/10.1038/s41586-02...
# 1811         1811  Publication: https://doi.org/10.1126/science.a...
# 1812         1812  Publication: https://doi.org/10.1038/s41586-02...
# 1813         1813  Publication: https://doi.org/10.1038/s41593-02...
# 1814         1814  Publication: https://doi.org/10.1038/s41593-02...
#
#                              collection_id  \
# 0     8e880741-bf9a-4c8e-9227-934204631d2a
# 1     8e880741-bf9a-4c8e-9227-934204631d2a
# 2     8e880741-bf9a-4c8e-9227-934204631d2a
# 3     8e880741-bf9a-4c8e-9227-934204631d2a
# 4     a96133de-e951-4e2d-ace6-59db8b3bfb1d
# ...                                    ...
# 1810  45d5d2c3-bc28-4814-aed6-0bb6f0e11c82
# 1811  e5f58829-1a66-40b5-a624-9046778e74f5
# 1812  45d5d2c3-bc28-4814-aed6-0bb6f0e11c82
# 1813  1ca90a2d-2943-483d-b678-b809bf464c30
# 1814  1ca90a2d-2943-483d-b678-b809bf464c30
#
#                                         collection_name  \
# 0     High Resolution Slide-seqV2 Spatial Transcript...
# 1     High Resolution Slide-seqV2 Spatial Transcript...
# 2     High Resolution Slide-seqV2 Spatial Transcript...
# 3     High Resolution Slide-seqV2 Spatial Transcript...
# 4     HTAN/HTAPP Broad - Spatio-molecular dissection...
# ...                                                 ...
# 1810  A single-cell transcriptional timelapse of mou...
# 1811                                     Tabula Sapiens
# 1812  A single-cell transcriptional timelapse of mou...
# 1813  SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
# 1814  SEA-AD: Seattle Alzheimer’s Disease Brain Cell...
#
#                   collection_doi  \
# 0     10.1016/j.isci.2022.104097
# 1     10.1016/j.isci.2022.104097
# 2     10.1016/j.isci.2022.104097
# 3     10.1016/j.isci.2022.104097
# 4     10.1038/s41591-024-03215-z
# ...                          ...
# 1810  10.1038/s41586-024-07069-w
# 1811     10.1126/science.abl4896
# 1812  10.1038/s41586-024-07069-w
# 1813  10.1038/s41593-024-01774-5
# 1814  10.1038/s41593-024-01774-5
#
#                                    collection_doi_label  \
# 0                       Marshall et al. (2022) iScience
# 1                       Marshall et al. (2022) iScience
# 2                       Marshall et al. (2022) iScience
# 3                       Marshall et al. (2022) iScience
# 4                      Klughammer et al. (2024) Nat Med
# ...                                                 ...
# 1810                           Qiu et al. (2024) Nature
# 1811  The Tabula Sapiens Consortium* et al. (2022) S...
# 1812                           Qiu et al. (2024) Nature
# 1813                 Gabitto et al. (2024) Nat Neurosci
# 1814                 Gabitto et al. (2024) Nat Neurosci
#
#                                 dataset_id  \
# 0     4eb29386-de81-452f-b3c0-e00844e8c7fd
# 1     78d59e4a-82eb-4a61-a1dc-da974d7ea54b
# 2     add5eb84-5fc9-4f01-982e-a346dd42ee82
# 3     b020294c-ab82-4547-b5a7-63d8ffa575ed
# 4     d7476ae2-e320-4703-8304-da5c42627e71
# ...                                    ...
# 1810  dcfa2614-7ca7-4d82-814c-350626eccb26
# 1811  53d208b0-2cfd-4366-9866-c3c6114081bc
# 1812  dcfd4feb-18a3-4b30-81d7-1b0c544a8ab3
# 1813  c2876b1b-06d8-4d96-a56b-5304f815b99a
# 1814  6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3
#
#                         dataset_version_id  \
# 0     66699060-0389-4fbd-b3a5-196b3b4e32d6
# 1     f64950a2-a3c8-490a-8431-7121eeb4f5f4
# 2     781a724a-b0f5-46c4-9a13-e6293ef4364f
# 3     96a79598-297b-4ade-a6c1-a431ab243548
# 4     ac9fe945-6784-48fa-a2d5-a8646196d37e
# ...                                    ...
# 1810  ca20ef35-13c0-4850-bec4-ba00e6bbd6f9
# 1811  5a495302-b7cd-4bf9-853e-95627b00bb03
# 1812  a5a85963-8004-41a1-8eb5-ca65266d89c3
# 1813  92b37feb-aa2c-40d7-bd90-0a9b5ddb3b27
# 1814  dad4819b-4c14-439c-b32a-2c8d68bd22e1
#
#                                           dataset_title  \
# 0      Spatial transcriptomics in mouse: Puck_191112_05
# 1      Spatial transcriptomics in mouse: Puck_191112_08
# 2      Spatial transcriptomics in mouse: Puck_191109_20
# 3      Spatial transcriptomics in mouse: Puck_191112_13
# 4                          HTAPP-330-SMP-1082 scRNA-seq
# ...                                                 ...
# 1810                       Major cell cluster: Mesoderm
# 1811                         Tabula Sapiens - All Cells
# 1812                     Whole dataset: Raw counts only
# 1813  Whole Taxonomy - MTG: Seattle Alzheimer's Dise...
# 1814  Whole Taxonomy - DLPFC: Seattle Alzheimer's Di...
#
#                               dataset_h5ad_path  dataset_total_cell_count
# 0     4eb29386-de81-452f-b3c0-e00844e8c7fd.h5ad                     10888
# 1     78d59e4a-82eb-4a61-a1dc-da974d7ea54b.h5ad                     10250
# 2     add5eb84-5fc9-4f01-982e-a346dd42ee82.h5ad                     12906
# 3     b020294c-ab82-4547-b5a7-63d8ffa575ed.h5ad                     15161
# 4     d7476ae2-e320-4703-8304-da5c42627e71.h5ad                       565
# ...                                         ...                       ...
# 1810  dcfa2614-7ca7-4d82-814c-350626eccb26.h5ad                   3267338
# 1811  53d208b0-2cfd-4366-9866-c3c6114081bc.h5ad                   1136218
# 1812  dcfd4feb-18a3-4b30-81d7-1b0c544a8ab3.h5ad                  11441407
# 1813  c2876b1b-06d8-4d96-a56b-5304f815b99a.h5ad                   1378211
# 1814  6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3.h5ad                   1395601
#
# [1815 rows x 11 columns]

# %% [markdown]
# ## Checking list of all assays and veryfying new ones

# %%
assays_old = census_old["census_data"]["homo_sapiens"].obs.read(column_names=["assay"]).concat().to_pandas().value_counts().reset_index()

# %%
assays_new = census_new["census_data"]["homo_sapiens"].obs.read(column_names=["assay"]).concat().to_pandas().value_counts().reset_index()

# %%
assays_merged = pd.merge(assays_old, assays_new, how="outer", on="assay")
assays_merged["delta"] = assays_merged["count_y"] - assays_merged["count_x"]
assays_merged = assays_merged.sort_values("count_y", ascending=False)
assays_merged
# Out:
#                                               assay     count_x   count_y  \
# 3                                         10x 3' v3  59668147.0  96655665
# 2                                         10x 3' v2  22750589.0  24507159
# 6                                         10x 5' v2   4363694.0   8748986
# 5                                         10x 5' v1   7448617.0   7683010
# 36                                     sci-RNA-seq3   5064268.0   5230353
# 8                                      10x multiome         NaN   3033426
# 4                    10x 5' transcription profiling   1968545.0   2125643
# 14                                         Drop-seq   1048377.0   1048377
# 23              ScaleBio single cell RNA sequencing    700524.0    700524
# 0                    10x 3' transcription profiling    665642.0    665642
# 33                                    microwell-seq    642559.0    642559
# 11         BD Rhapsody Whole Transcriptome Analysis    269298.0    269298
# 28                                       Smart-seq2    260350.0    267948
# 24                                         Seq-Well    255232.0    255232
# 1                                         10x 3' v1    213017.0    232475
# 31                                           inDrop     51304.0    136019
# 30                                          TruDrop    133507.0    133507
# 15                              GEXSCOPE technology    117962.0    117962
# 7                          10x gene expression flex     86356.0    117356
# 10                        BD Rhapsody Targeted mRNA     96145.0     96145
# 21                                        SPLiT-seq     81936.0     81936
# 17                                         MARS-seq     70146.0     70146
# 27                                     Smart-seq v4     63920.0     63920
# 35  particle-templated instant partition sequencing         NaN     46500
# 25                                      Seq-Well S3     41560.0     41560
# 32                                          mCT-seq         NaN     37121
# 16             HIVE CLX Single-Cell RNAseq Solution         NaN     31000
# 13                                         CEL-seq2     25416.0     25416
# 9                             Asteria scRNA-seq kit         NaN     15764
# 18            Parse Evercode Whole Transcriptome v2         NaN     15500
# 20                                         SORT-seq     11640.0     11640
# 22                                         STRT-seq     11357.0      9386
# 29                                       Smart-seq3      5005.0      5005
# 19                                       Quartz-seq      2882.0      2882
# 34                                modified STRT-seq         NaN      1971
# 12                                          CEL-seq         NaN       796
# 26                                        Smart-seq       172.0       172
#
#          delta
# 3   36987518.0
# 2    1756570.0
# 6    4385292.0
# 5     234393.0
# 36    166085.0
# 8          NaN
# 4     157098.0
# 14         0.0
# 23         0.0
# 0          0.0
# 33         0.0
# 11         0.0
# 28      7598.0
# 24         0.0
# 1      19458.0
# 31     84715.0
# 30         0.0
# 15         0.0
# 7      31000.0
# 10         0.0
# 21         0.0
# 17         0.0
# 27         0.0
# 35         NaN
# 25         0.0
# 32         NaN
# 16         NaN
# 13         0.0
# 9          NaN
# 18         NaN
# 20         0.0
# 22     -1971.0
# 29         0.0
# 19         0.0
# 34         NaN
# 12         NaN
# 26         0.0

# %% [markdown]
# ## Normalized layer for SMART-like data

# %%
# From https://github.com/chanzuckerberg/cellxgene-census/blob/7d3ab1bbaa30dec8b09a96ec38c21374b0073333/tools/cellxgene_census_builder/src/cellxgene_census_builder/build_soma/globals.py#L336 
FULL_GENE_ASSAY = {
    "EFO:0003755": "FL-cDNA",
    "EFO:0008747": "FRISCR",
    "EFO:0008763": "Hi-SCL",
    "EFO:0008797": "MATQ-seq",
    "EFO:0008877": "Quartz-seq",
    "EFO:0008930": "Smart-seq",
    "EFO:0008931": "Smart-seq2",
    "EFO:0008956": "SUPeR-seq",
    "EFO:0009999": "G&T-Seq",
    "EFO:0010004": "SCRB-seq",
    "EFO:0010006": "scM&T-seq",
    "EFO:0010022": "Smart-3Seq",
    "EFO:0010058": "Fluidigm C1-based SMARTer library preparation",
    "EFO:0010184": "Smart-like",
    "EFO:0022396": "TruSeq",
    "EFO:0022488": "Smart-seq3",
    "EFO:0022839": "STORM-seq",
    "EFO:0030031": "SCOPE-chip",
    "EFO:0030060": "mCT-seq",
    "EFO:0030061": "mcSCRB-seq",
    "EFO:0700016": "Smart-seq v4",
}

# %%
assays_new_full_gene = assays_merged[assays_merged["assay"].isin(FULL_GENE_ASSAY.values())]
assays_new_full_gene
# Out:
#            assay   count_x  count_y   delta
# 28    Smart-seq2  260350.0   267948  7598.0
# 27  Smart-seq v4   63920.0    63920     0.0
# 32       mCT-seq       NaN    37121     NaN
# 29    Smart-seq3    5005.0     5005     0.0
# 19    Quartz-seq    2882.0     2882     0.0
# 26     Smart-seq     172.0      172     0.0

# %%
# get a few cells from each assay present
smartseq1_ids = census_new["census_data"]["homo_sapiens"].obs.read(column_names=["soma_joinid"], value_filter = f"assay == 'Quartz-seq'").concat().to_pandas()
smartseq4_ids = census_new["census_data"]["homo_sapiens"].obs.read(column_names=["soma_joinid"], value_filter = f"assay == 'Smart-seq v4'").concat().to_pandas()

smartseq = smartseq1_ids["soma_joinid"].tolist()[:1000] + smartseq4_ids["soma_joinid"].tolist()[:1000]

adata = cellxgene_census.get_anndata(
    census_new,
    organism="homo_sapiens",
    obs_coords=smartseq,
    X_layers=["normalized"]
)
# Out:
# /home/ubuntu/miniconda3/envs/sc/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /home/ubuntu/miniconda3/envs/sc/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
adata.layers["normalized"]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 13036267 stored elements and shape (2000, 61479)>

# %%
adata.obs["assay"].drop_duplicates()
# Out:
# 0       Smart-seq v4
# 1000      Quartz-seq
# Name: assay, dtype: category
# Categories (37, object): ['10x 3' transcription profiling', '10x 3' v1', '10x 3' v2', '10x 3' v3', ..., 'microwell-seq', 'modified STRT-seq', 'particle-templated instant partition sequencing', 'sci-RNA-seq3']

# %%
min(adata.layers["normalized"].data)
# Out:
# np.float32(5.2735913e-09)

# %%
max(adata.layers["normalized"].data)
# Out:
# np.float32(0.063144684)

# %%
adata.layers["normalized"].sum(axis=1).min()
# Out:
# np.float32(0.99999875)

# %%
adata.layers["normalized"].sum(axis=1).max()
# Out:
# np.float32(1.0000011)

# %%
adata.layers["normalized_local"] = adata.X.copy()
adata.layers["normalized_local"] = csr_matrix(adata.layers["normalized_local"].multiply(1 / adata.var["feature_length"].values[None,:]))
adata.layers["normalized_local"] = csr_matrix(adata.layers["normalized_local"].multiply( 1 / adata.layers["normalized_local"].sum(1).A))

# %%
adata.layers["normalized_local"].data
# Out:
# array([2.45865267e-05, 2.83067595e-06, 2.67409696e-05, ...,
#        8.28286526e-05, 7.54188263e-05, 1.28428137e-04], shape=(13036267,))

# %%
adata.layers["normalized"].data
# Out:
# array([2.4586450e-05, 2.8306968e-06, 2.6741065e-05, ..., 8.2828104e-05,
#        7.5418502e-05, 1.2842938e-04], shape=(13036267,), dtype=float32)

# %%
pre_calc = adata.layers["normalized"].data.copy()
fly_calc = adata.layers["normalized_local"].data.copy()
for r in reversed(range(11)):
    n_differing = np.nonzero(np.round(pre_calc.copy(), r).astype(np.float32) != np.round(fly_calc.copy(), r).astype(np.float32))[0].shape[0]
    percent_differing = n_differing / fly_calc.shape[0]
    print("Decimal points: ", r, " values differing: n = ", n_differing, ", fracion = ", percent_differing)
# Out:
# Decimal points:  10  values differing: n =  9389378 , fracion =  0.7202505134330249
# Decimal points:  9  values differing: n =  4750525 , fracion =  0.364408384700927
# Decimal points:  8  values differing: n =  924218 , fracion =  0.07089590908194808
# Decimal points:  7  values differing: n =  108095 , fracion =  0.008291867602895828
# Decimal points:  6  values differing: n =  11142 , fracion =  0.0008546925281600937
# Decimal points:  5  values differing: n =  1096 , fracion =  8.407314762730772e-05
# Decimal points:  4  values differing: n =  136 , fracion =  1.0432434377111177e-05
# Decimal points:  3  values differing: n =  2 , fracion =  1.5341815260457615e-07
# Decimal points:  2  values differing: n =  0 , fracion =  0.0
# Decimal points:  1  values differing: n =  0 , fracion =  0.0
# Decimal points:  0  values differing: n =  0 , fracion =  0.0

# %% [markdown]
# ## Checking discover schema 7 changes
#
# ###  Field diff in obs/var

# %%
for organism in census_old["census_data"].keys():
    print(f"\n## {organism}")
    old_columns = list(census_old["census_data"][organism].obs.keys())
    new_columns = list(census_new["census_data"][organism].obs.keys())

    print(f"Shared obs columns: {sorted(set(old_columns) & set(new_columns))}")
    print(f"New obs columns: {sorted(set(new_columns) - set(old_columns))}")
    print(f"Removed obs columns: {sorted(set(old_columns) - set(new_columns))}")
# Out:
# ## homo_sapiens
# Shared obs columns: ['assay', 'assay_ontology_term_id', 'cell_type', 'cell_type_ontology_term_id', 'dataset_id', 'development_stage', 'development_stage_ontology_term_id', 'disease', 'disease_ontology_term_id', 'donor_id', 'is_primary_data', 'n_measured_vars', 'nnz', 'observation_joinid', 'raw_mean_nnz', 'raw_sum', 'raw_variance_nnz', 'self_reported_ethnicity', 'self_reported_ethnicity_ontology_term_id', 'sex', 'sex_ontology_term_id', 'soma_joinid', 'suspension_type', 'tissue', 'tissue_general', 'tissue_general_ontology_term_id', 'tissue_ontology_term_id', 'tissue_type']
# New obs columns: []
# Removed obs columns: []
#
# ## mus_musculus
# Shared obs columns: ['assay', 'assay_ontology_term_id', 'cell_type', 'cell_type_ontology_term_id', 'dataset_id', 'development_stage', 'development_stage_ontology_term_id', 'disease', 'disease_ontology_term_id', 'donor_id', 'is_primary_data', 'n_measured_vars', 'nnz', 'observation_joinid', 'raw_mean_nnz', 'raw_sum', 'raw_variance_nnz', 'self_reported_ethnicity', 'self_reported_ethnicity_ontology_term_id', 'sex', 'sex_ontology_term_id', 'soma_joinid', 'suspension_type', 'tissue', 'tissue_general', 'tissue_general_ontology_term_id', 'tissue_ontology_term_id', 'tissue_type']
# New obs columns: []
# Removed obs columns: []

# %%
for organism in census_old["census_data"].keys():
    print(f"\n## {organism}")
    old_columns = list(census_old["census_data"][organism].ms["RNA"].var.keys())
    new_columns = list(census_new["census_data"][organism].ms["RNA"].var.keys())

    print(f"Shared obs columns: {sorted(set(old_columns) & set(new_columns))}")
    print(f"New obs columns: {sorted(set(new_columns) - set(old_columns))}")
    print(f"Removed obs columns: {sorted(set(old_columns) - set(new_columns))}")
# Out:
# ## homo_sapiens
# Shared obs columns: ['feature_id', 'feature_length', 'feature_name', 'feature_type', 'n_measured_obs', 'nnz', 'soma_joinid']
# New obs columns: []
# Removed obs columns: []
#
# ## mus_musculus
# Shared obs columns: ['feature_id', 'feature_length', 'feature_name', 'feature_type', 'n_measured_obs', 'nnz', 'soma_joinid']
# New obs columns: []
# Removed obs columns: []

# %% [markdown]
# ### New organisms

# %%
n_cells = census_new["census_data"][organism].ms["RNA"].X["raw"].shape
n_cells
# Out:
# (43653561, 53384)

# %%
for organism in census_new["census_data"].keys():
    print(f"\n## {organism}")
    n_cells = census_new["census_data"][organism].obs.domain[0][1]+1
    n_cell_x = census_new["census_data"][organism].ms["RNA"].X["raw"].shape[0]
    print(f"Number of obs cells: {n_cells}")
    print(f"Number of X cells: {n_cell_x}")

    n_genes = census_new["census_data"][organism].ms["RNA"].var.domain[0][1]+1
    n_gene_x = census_new["census_data"][organism].ms["RNA"].X["raw"].shape[1]
    print(f"Number of var genes: {n_genes}")
    print(f"Number of X genes: {n_gene_x}")

    adata = cellxgene_census.get_anndata(
        census_new,
        organism=organism,
        measurement_name="RNA",
        X_name="raw",
        X_layers=["normalized"],
        obs_coords=list(range(1000))
    )

    print("Min raw X value: ", adata.X.data.min())
    print("Max raw X value: ", adata.X.data.max())
    print("Min normalized X value: ", adata.layers["normalized"].data.min())
    print("Max normalized X value: ", adata.layers["normalized"].data.max())
    print("N obs cols: ", adata.obs.shape[1])
    print("N var cols: ", adata.var.shape[1])
    print("Obs columns: ", ", ".join(adata.obs.columns.astype(str).tolist()))
    
    for obs in adata.obs.columns:
        first_elements = ",".join(adata.obs[obs].astype(str).tolist()[:5])
        print(f"  First 5 elements of obs column {obs}: {first_elements}")

    for var in adata.var.columns:
        first_elements = ",".join(adata.var[var].astype(str).tolist()[:5])
        print(f"  First 5 elements of var column {var}: {first_elements}")
# Out:
# ## callithrix_jacchus
# Number of obs cells: 2275451
# Number of X cells: 2275451
# Number of var genes: 28348
# Number of X genes: 28348
# /home/ubuntu/miniconda3/envs/sc/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /home/ubuntu/miniconda3/envs/sc/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# Min raw X value:  1.0
# Max raw X value:  301.0
# Min normalized X value:  1.9187108e-05
# Max normalized X value:  0.043024063
# N obs cols:  28
# N var cols:  7
# Obs columns:  soma_joinid, dataset_id, assay, assay_ontology_term_id, cell_type, cell_type_ontology_term_id, development_stage, development_stage_ontology_term_id, disease, disease_ontology_term_id, donor_id, is_primary_data, observation_joinid, self_reported_ethnicity, self_reported_ethnicity_ontology_term_id, sex, sex_ontology_term_id, suspension_type, tissue, tissue_ontology_term_id, tissue_type, tissue_general, tissue_general_ontology_term_id, raw_sum, nnz, raw_mean_nnz, raw_variance_nnz, n_measured_vars
#   First 5 elements of obs column soma_joinid: 0,1,2,3,4
#   First 5 elements of obs column dataset_id: 787138a6-a421-444e-8ae5-537c1842e70c,787138a6-a421-444e-8ae5-537c1842e70c,787138a6-a421-444e-8ae5-537c1842e70c,787138a6-a421-444e-8ae5-537c1842e70c,787138a6-a421-444e-8ae5-537c1842e70c
#   First 5 elements of obs column assay: 10x 3' v3,10x 3' v3,10x 3' v3,10x 3' v3,10x 3' v3
#   First 5 elements of obs column assay_ontology_term_id: EFO:0009922,EFO:0009922,EFO:0009922,EFO:0009922,EFO:0009922
#   First 5 elements of obs column cell_type: leptomeningeal cell,leptomeningeal cell,endothelial cell,endothelial cell,oligodendrocyte
#   First 5 elements of obs column cell_type_ontology_term_id: CL:0000708,CL:0000708,CL:0000115,CL:0000115,CL:0000128
#   First 5 elements of obs column development_stage: post-juvenile adult stage,post-juvenile adult stage,post-juvenile adult stage,post-juvenile adult stage,post-juvenile adult stage
#   First 5 elements of obs column development_stage_ontology_term_id: UBERON:0000113,UBERON:0000113,UBERON:0000113,UBERON:0000113,UBERON:0000113
#   First 5 elements of obs column disease: normal,normal,normal,normal,normal
#   First 5 elements of obs column disease_ontology_term_id: PATO:0000461,PATO:0000461,PATO:0000461,PATO:0000461,PATO:0000461
#   First 5 elements of obs column donor_id: bi005,bi005,bi005,bi005,bi005
#   First 5 elements of obs column is_primary_data: False,False,False,False,False
#   First 5 elements of obs column observation_joinid: hGj_LOlX@R,y_Pdgpv;qS,jLe2(pDnD2,JEPb(Z{+8u,b@`Y%gX}@X
#   First 5 elements of obs column self_reported_ethnicity: na,na,na,na,na
#   First 5 elements of obs column self_reported_ethnicity_ontology_term_id: na,na,na,na,na
#   First 5 elements of obs column sex: male,male,male,male,male
#   First 5 elements of obs column sex_ontology_term_id: PATO:0000384,PATO:0000384,PATO:0000384,PATO:0000384,PATO:0000384
#   First 5 elements of obs column suspension_type: nucleus,nucleus,nucleus,nucleus,nucleus
#   First 5 elements of obs column tissue: primary motor cortex,primary motor cortex,primary motor cortex,primary motor cortex,primary motor cortex
#   First 5 elements of obs column tissue_ontology_term_id: UBERON:0001384,UBERON:0001384,UBERON:0001384,UBERON:0001384,UBERON:0001384
#   First 5 elements of obs column tissue_type: tissue,tissue,tissue,tissue,tissue
#   First 5 elements of obs column tissue_general: brain,brain,brain,brain,brain
#   First 5 elements of obs column tissue_general_ontology_term_id: UBERON:0000955,UBERON:0000955,UBERON:0000955,UBERON:0000955,UBERON:0000955
#   First 5 elements of obs column raw_sum: 18692.0,14319.0,12628.0,12443.0,10260.0
#   First 5 elements of obs column nnz: 5262,4584,4582,4578,3842
#   First 5 elements of obs column raw_mean_nnz: 3.5522614975294564,3.12369109947644,2.756001745962462,2.717999126256007,2.670484122852681
#   First 5 elements of obs column raw_variance_nnz: 57.42009657635039,42.99167949958474,17.186904595500117,12.299964359186475,26.22672035915946
#   First 5 elements of obs column n_measured_vars: 14409,14409,14409,14409,14409
#   First 5 elements of var column soma_joinid: 0,1,2,3,4
#   First 5 elements of var column feature_id: ENSCJAG00000000314,ENSCJAG00000005045,ENSCJAG00000018756,ENSCJAG00000001190,ENSCJAG00000002444
#   First 5 elements of var column feature_name: A1BG,A1CF,A2ML1,A3GALT2,A4GNT
#   First 5 elements of var column feature_type: protein_coding,protein_coding,protein_coding,protein_coding,protein_coding
#   First 5 elements of var column feature_length: 2286,1994,4299,1020,1023
#   First 5 elements of var column nnz: 5510,1537,27463,24380,232
#   First 5 elements of var column n_measured_obs: 2086650,247040,2271925,2271925,247040
#
# ## homo_sapiens
# Number of obs cells: 153128001
# Number of X cells: 153128001
# Number of var genes: 61479
# Number of X genes: 61479
# /home/ubuntu/miniconda3/envs/sc/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /home/ubuntu/miniconda3/envs/sc/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# Min raw X value:  1.0
# Max raw X value:  11551.0
# Min normalized X value:  1.8775929e-05
# Max normalized X value:  0.91412354
# N obs cols:  28
# N var cols:  7
# Obs columns:  soma_joinid, dataset_id, assay, assay_ontology_term_id, cell_type, cell_type_ontology_term_id, development_stage, development_stage_ontology_term_id, disease, disease_ontology_term_id, donor_id, is_primary_data, observation_joinid, self_reported_ethnicity, self_reported_ethnicity_ontology_term_id, sex, sex_ontology_term_id, suspension_type, tissue, tissue_ontology_term_id, tissue_type, tissue_general, tissue_general_ontology_term_id, raw_sum, nnz, raw_mean_nnz, raw_variance_nnz, n_measured_vars
#   First 5 elements of obs column soma_joinid: 0,1,2,3,4
#   First 5 elements of obs column dataset_id: d7476ae2-e320-4703-8304-da5c42627e71,d7476ae2-e320-4703-8304-da5c42627e71,d7476ae2-e320-4703-8304-da5c42627e71,d7476ae2-e320-4703-8304-da5c42627e71,d7476ae2-e320-4703-8304-da5c42627e71
#   First 5 elements of obs column assay: 10x 3' v3,10x 3' v3,10x 3' v3,10x 3' v3,10x 3' v3
#   First 5 elements of obs column assay_ontology_term_id: EFO:0009922,EFO:0009922,EFO:0009922,EFO:0009922,EFO:0009922
#   First 5 elements of obs column cell_type: endothelial cell,malignant cell,fibroblast,fibroblast,macrophage
#   First 5 elements of obs column cell_type_ontology_term_id: CL:0000115,CL:0001064,CL:0000057,CL:0000057,CL:0000235
#   First 5 elements of obs column development_stage: 29-year-old stage,29-year-old stage,29-year-old stage,29-year-old stage,29-year-old stage
#   First 5 elements of obs column development_stage_ontology_term_id: HsapDv:0000123,HsapDv:0000123,HsapDv:0000123,HsapDv:0000123,HsapDv:0000123
#   First 5 elements of obs column disease: breast cancer,breast cancer,breast cancer,breast cancer,breast cancer
#   First 5 elements of obs column disease_ontology_term_id: MONDO:0007254,MONDO:0007254,MONDO:0007254,MONDO:0007254,MONDO:0007254
#   First 5 elements of obs column donor_id: HTAPP-330,HTAPP-330,HTAPP-330,HTAPP-330,HTAPP-330
#   First 5 elements of obs column is_primary_data: False,False,False,False,False
#   First 5 elements of obs column observation_joinid: qsW0>t$X%X,>SS{_^o99U,na+Cy?0^77,i%wMdi?~p+,E0Ifjd2j@h
#   First 5 elements of obs column self_reported_ethnicity: unknown,unknown,unknown,unknown,unknown
#   First 5 elements of obs column self_reported_ethnicity_ontology_term_id: unknown,unknown,unknown,unknown,unknown
#   First 5 elements of obs column sex: female,female,female,female,female
#   First 5 elements of obs column sex_ontology_term_id: PATO:0000383,PATO:0000383,PATO:0000383,PATO:0000383,PATO:0000383
#   First 5 elements of obs column suspension_type: cell,cell,cell,cell,cell
#   First 5 elements of obs column tissue: liver,liver,liver,liver,liver
#   First 5 elements of obs column tissue_ontology_term_id: UBERON:0002107,UBERON:0002107,UBERON:0002107,UBERON:0002107,UBERON:0002107
#   First 5 elements of obs column tissue_type: tissue,tissue,tissue,tissue,tissue
#   First 5 elements of obs column tissue_general: liver,liver,liver,liver,liver
#   First 5 elements of obs column tissue_general_ontology_term_id: UBERON:0002107,UBERON:0002107,UBERON:0002107,UBERON:0002107,UBERON:0002107
#   First 5 elements of obs column raw_sum: 19636.0,17245.0,14629.0,13740.0,12701.0
#   First 5 elements of obs column nnz: 7152,5382,3940,5010,4420
#   First 5 elements of obs column raw_mean_nnz: 2.745525727069351,3.204199182460052,3.712944162436548,2.7425149700598803,2.873529411764706
#   First 5 elements of obs column raw_variance_nnz: 696.6162574217965,394.56914794619524,1603.1810966863964,347.04808231411005,422.6350538450275
#   First 5 elements of obs column n_measured_vars: 12621,12621,12621,12621,12621
#   First 5 elements of var column soma_joinid: 0,1,2,3,4
#   First 5 elements of var column feature_id: ENSG00000237491,ENSG00000188976,ENSG00000187642,ENSG00000272512,ENSG00000188290
#   First 5 elements of var column feature_name: LINC01409,NOC2L,PERM1,ENSG00000272512,HES4
#   First 5 elements of var column feature_type: lncRNA,protein_coding,protein_coding,lncRNA,protein_coding
#   First 5 elements of var column feature_length: 1089,1244,2765,2086,961
#   First 5 elements of var column nnz: 12451983,25164122,820116,1171001,23964448
#   First 5 elements of var column n_measured_obs: 138403531,152794359,142875264,137527561,152776134
#
# ## macaca_mulatta
# Number of obs cells: 7010229
# Number of X cells: 7010229
# Number of var genes: 34676
# Number of X genes: 34676
# /home/ubuntu/miniconda3/envs/sc/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /home/ubuntu/miniconda3/envs/sc/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# Min raw X value:  1.0
# Max raw X value:  231.0
# Min normalized X value:  0.00018556416
# Max normalized X value:  0.5714264
# N obs cols:  28
# N var cols:  7
# Obs columns:  soma_joinid, dataset_id, assay, assay_ontology_term_id, cell_type, cell_type_ontology_term_id, development_stage, development_stage_ontology_term_id, disease, disease_ontology_term_id, donor_id, is_primary_data, observation_joinid, self_reported_ethnicity, self_reported_ethnicity_ontology_term_id, sex, sex_ontology_term_id, suspension_type, tissue, tissue_ontology_term_id, tissue_type, tissue_general, tissue_general_ontology_term_id, raw_sum, nnz, raw_mean_nnz, raw_variance_nnz, n_measured_vars
#   First 5 elements of obs column soma_joinid: 0,1,2,3,4
#   First 5 elements of obs column dataset_id: 885d325f-b478-408b-b184-510b4db4f85f,885d325f-b478-408b-b184-510b4db4f85f,885d325f-b478-408b-b184-510b4db4f85f,885d325f-b478-408b-b184-510b4db4f85f,885d325f-b478-408b-b184-510b4db4f85f
#   First 5 elements of obs column assay: sci-RNA-seq3,sci-RNA-seq3,sci-RNA-seq3,sci-RNA-seq3,sci-RNA-seq3
#   First 5 elements of obs column assay_ontology_term_id: EFO:0030028,EFO:0030028,EFO:0030028,EFO:0030028,EFO:0030028
#   First 5 elements of obs column cell_type: serotonergic neuron,serotonergic neuron,serotonergic neuron,serotonergic neuron,serotonergic neuron
#   First 5 elements of obs column cell_type_ontology_term_id: CL:0000850,CL:0000850,CL:0000850,CL:0000850,CL:0000850
#   First 5 elements of obs column development_stage: prime adult stage,prime adult stage,prime adult stage,prime adult stage,prime adult stage
#   First 5 elements of obs column development_stage_ontology_term_id: UBERON:0018241,UBERON:0018241,UBERON:0018241,UBERON:0018241,UBERON:0018241
#   First 5 elements of obs column disease: normal,normal,normal,normal,normal
#   First 5 elements of obs column disease_ontology_term_id: PATO:0000461,PATO:0000461,PATO:0000461,PATO:0000461,PATO:0000461
#   First 5 elements of obs column donor_id: CPRC_animal_id:6J2,CPRC_animal_id:6J2,CPRC_animal_id:6J2,CPRC_animal_id:6J2,CPRC_animal_id:6J2
#   First 5 elements of obs column is_primary_data: False,False,False,False,False
#   First 5 elements of obs column observation_joinid: A~B^dDGk3U,;l;z-H`{lx,;1hQlR!gEx,Yv?Msd%OYj,&7I5!1n<}J
#   First 5 elements of obs column self_reported_ethnicity: na,na,na,na,na
#   First 5 elements of obs column self_reported_ethnicity_ontology_term_id: na,na,na,na,na
#   First 5 elements of obs column sex: male,male,male,male,male
#   First 5 elements of obs column sex_ontology_term_id: PATO:0000384,PATO:0000384,PATO:0000384,PATO:0000384,PATO:0000384
#   First 5 elements of obs column suspension_type: nucleus,nucleus,nucleus,nucleus,nucleus
#   First 5 elements of obs column tissue: nucleus accumbens,nucleus accumbens,nucleus accumbens,nucleus accumbens,nucleus accumbens
#   First 5 elements of obs column tissue_ontology_term_id: UBERON:0001882,UBERON:0001882,UBERON:0001882,UBERON:0001882,UBERON:0001882
#   First 5 elements of obs column tissue_type: tissue,tissue,tissue,tissue,tissue
#   First 5 elements of obs column tissue_general: brain,brain,brain,brain,brain
#   First 5 elements of obs column tissue_general_ontology_term_id: UBERON:0000955,UBERON:0000955,UBERON:0000955,UBERON:0000955,UBERON:0000955
#   First 5 elements of obs column raw_sum: 180.0,217.0,136.0,238.0,157.0
#   First 5 elements of obs column nnz: 132,181,112,202,131
#   First 5 elements of obs column raw_mean_nnz: 1.3636363636363635,1.1988950276243093,1.2142857142857142,1.1782178217821782,1.1984732824427482
#   First 5 elements of obs column raw_variance_nnz: 1.7751561415683554,1.7157765500306936,0.47619047619047616,0.47554307669572926,0.498766881972989
#   First 5 elements of obs column n_measured_vars: 29060,29060,29060,29060,29060
#   First 5 elements of var column soma_joinid: 0,1,2,3,4
#   First 5 elements of var column feature_id: ENSMMUG00000000001,ENSMMUG00000000002,ENSMMUG00000000005,ENSMMUG00000000006,ENSMMUG00000000007
#   First 5 elements of var column feature_name: CCNF,TEDC2,NAGA,NEURL3,BET1
#   First 5 elements of var column feature_type: protein_coding,protein_coding,protein_coding,protein_coding,protein_coding
#   First 5 elements of var column feature_length: 3240,1749,1942,2872,369
#   First 5 elements of var column nnz: 81816,9256,23006,1316,39185
#   First 5 elements of var column n_measured_obs: 7010229,7010229,7010229,7010229,7010229
#
# ## mus_musculus
# Number of obs cells: 43653561
# Number of X cells: 43653561
# Number of var genes: 53384
# Number of X genes: 53384
# /home/ubuntu/miniconda3/envs/sc/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /home/ubuntu/miniconda3/envs/sc/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# Min raw X value:  1.0
# Max raw X value:  1499.0
# Min normalized X value:  8.5236505e-05
# Max normalized X value:  0.31488037
# N obs cols:  28
# N var cols:  7
# Obs columns:  soma_joinid, dataset_id, assay, assay_ontology_term_id, cell_type, cell_type_ontology_term_id, development_stage, development_stage_ontology_term_id, disease, disease_ontology_term_id, donor_id, is_primary_data, observation_joinid, self_reported_ethnicity, self_reported_ethnicity_ontology_term_id, sex, sex_ontology_term_id, suspension_type, tissue, tissue_ontology_term_id, tissue_type, tissue_general, tissue_general_ontology_term_id, raw_sum, nnz, raw_mean_nnz, raw_variance_nnz, n_measured_vars
#   First 5 elements of obs column soma_joinid: 0,1,2,3,4
#   First 5 elements of obs column dataset_id: a810e511-c18b-4b2a-8fdf-98a6a0d433a7,a810e511-c18b-4b2a-8fdf-98a6a0d433a7,a810e511-c18b-4b2a-8fdf-98a6a0d433a7,a810e511-c18b-4b2a-8fdf-98a6a0d433a7,a810e511-c18b-4b2a-8fdf-98a6a0d433a7
#   First 5 elements of obs column assay: 10x 3' v2,10x 3' v2,10x 3' v2,10x 3' v2,10x 3' v2
#   First 5 elements of obs column assay_ontology_term_id: EFO:0009899,EFO:0009899,EFO:0009899,EFO:0009899,EFO:0009899
#   First 5 elements of obs column cell_type: fibroblast of connective tissue of prostate,fibroblast of connective tissue of prostate,fibroblast of connective tissue of prostate,fibroblast of connective tissue of prostate,fibroblast of connective tissue of prostate
#   First 5 elements of obs column cell_type_ontology_term_id: CL:1000299,CL:1000299,CL:1000299,CL:1000299,CL:1000299
#   First 5 elements of obs column development_stage: 2-month-old stage,2-month-old stage,2-month-old stage,2-month-old stage,2-month-old stage
#   First 5 elements of obs column development_stage_ontology_term_id: MmusDv:0000062,MmusDv:0000062,MmusDv:0000062,MmusDv:0000062,MmusDv:0000062
#   First 5 elements of obs column disease: normal,normal,normal,normal,normal
#   First 5 elements of obs column disease_ontology_term_id: PATO:0000461,PATO:0000461,PATO:0000461,PATO:0000461,PATO:0000461
#   First 5 elements of obs column donor_id: musAd001,musAd001,musAd001,musAd001,musAd001
#   First 5 elements of obs column is_primary_data: False,False,False,False,False
#   First 5 elements of obs column observation_joinid: @nmg?SvW93,3~(zUB2cU3,h}yb5usIXV,g$;axA2`2T,6<Szc0%b+%
#   First 5 elements of obs column self_reported_ethnicity: na,na,na,na,na
#   First 5 elements of obs column self_reported_ethnicity_ontology_term_id: na,na,na,na,na
#   First 5 elements of obs column sex: male,male,male,male,male
#   First 5 elements of obs column sex_ontology_term_id: PATO:0000384,PATO:0000384,PATO:0000384,PATO:0000384,PATO:0000384
#   First 5 elements of obs column suspension_type: cell,cell,cell,cell,cell
#   First 5 elements of obs column tissue: prostate gland,prostate gland,prostate gland,prostate gland,prostate gland
#   First 5 elements of obs column tissue_ontology_term_id: UBERON:0002367,UBERON:0002367,UBERON:0002367,UBERON:0002367,UBERON:0002367
#   First 5 elements of obs column tissue_type: tissue,tissue,tissue,tissue,tissue
#   First 5 elements of obs column tissue_general: prostate gland,prostate gland,prostate gland,prostate gland,prostate gland
#   First 5 elements of obs column tissue_general_ontology_term_id: UBERON:0002367,UBERON:0002367,UBERON:0002367,UBERON:0002367,UBERON:0002367
#   First 5 elements of obs column raw_sum: 2019.0,2789.0,1996.0,2238.0,2561.0
#   First 5 elements of obs column nnz: 1018,1123,966,981,1194
#   First 5 elements of obs column raw_mean_nnz: 1.9833005893909628,2.483526268922529,2.0662525879917184,2.2813455657492354,2.144891122278057
#   First 5 elements of obs column raw_variance_nnz: 12.698835899724333,32.763320174665836,61.015295165148736,18.481988391686947,67.07286993784233
#   First 5 elements of obs column n_measured_vars: 19344,19344,19344,19344,19344
#   First 5 elements of var column soma_joinid: 0,1,2,3,4
#   First 5 elements of var column feature_id: ENSMUSG00000021124,ENSMUSG00000039377,ENSMUSG00000085604,ENSMUSG00000085125,ENSMUSG00000029439
#   First 5 elements of var column feature_name: Vti1b,Hlx,Dhx58os,Gm16070,Sfswap
#   First 5 elements of var column feature_type: protein_coding,protein_coding,lncRNA,lncRNA,protein_coding
#   First 5 elements of var column feature_length: 841,1495,897,2024,692
#   First 5 elements of var column nnz: 7232717,521246,130164,2290557,17837941
#   First 5 elements of var column n_measured_obs: 43653561,43518432,41430375,42056246,43653561
#
# ## pan_troglodytes
# Number of obs cells: 158099
# Number of X cells: 158099
# Number of var genes: 23534
# Number of X genes: 23534
# Min raw X value:  1.0
# Max raw X value:  502.0
# Min normalized X value:  2.9166229e-05
# Max normalized X value:  0.039647102
# N obs cols:  28
# N var cols:  7
# Obs columns:  soma_joinid, dataset_id, assay, assay_ontology_term_id, cell_type, cell_type_ontology_term_id, development_stage, development_stage_ontology_term_id, disease, disease_ontology_term_id, donor_id, is_primary_data, observation_joinid, self_reported_ethnicity, self_reported_ethnicity_ontology_term_id, sex, sex_ontology_term_id, suspension_type, tissue, tissue_ontology_term_id, tissue_type, tissue_general, tissue_general_ontology_term_id, raw_sum, nnz, raw_mean_nnz, raw_variance_nnz, n_measured_vars
#   First 5 elements of obs column soma_joinid: 0,1,2,3,4
#   First 5 elements of obs column dataset_id: 070b36c0-773a-45d7-ac44-92f690aee9ca,070b36c0-773a-45d7-ac44-92f690aee9ca,070b36c0-773a-45d7-ac44-92f690aee9ca,070b36c0-773a-45d7-ac44-92f690aee9ca,070b36c0-773a-45d7-ac44-92f690aee9ca
#   First 5 elements of obs column assay: 10x 3' v3,10x 3' v3,10x 3' v3,10x 3' v3,10x 3' v3
#   First 5 elements of obs column assay_ontology_term_id: EFO:0009922,EFO:0009922,EFO:0009922,EFO:0009922,EFO:0009922
#   First 5 elements of obs column cell_type: astrocyte,L2/3 intratelencephalic projecting glutamatergic neuron,astrocyte,sst GABAergic cortical interneuron,astrocyte
#   First 5 elements of obs column cell_type_ontology_term_id: CL:0000127,CL:4030059,CL:0000127,CL:4023017,CL:0000127
#   First 5 elements of obs column development_stage: prime adult stage,prime adult stage,prime adult stage,prime adult stage,prime adult stage
#   First 5 elements of obs column development_stage_ontology_term_id: UBERON:0018241,UBERON:0018241,UBERON:0018241,UBERON:0018241,UBERON:0018241
#   First 5 elements of obs column disease: normal,normal,normal,normal,normal
#   First 5 elements of obs column disease_ontology_term_id: PATO:0000461,PATO:0000461,PATO:0000461,PATO:0000461,PATO:0000461
#   First 5 elements of obs column donor_id: PTB165,PTB165,PTB165,PTB165,PTB165
#   First 5 elements of obs column is_primary_data: True,True,True,True,True
#   First 5 elements of obs column observation_joinid: <|^L79Wk0G,WEfB+lf$7k,E%H#yyY|{0,LT1*ocmvdK,Xv6QW9>HG_
#   First 5 elements of obs column self_reported_ethnicity: na,na,na,na,na
#   First 5 elements of obs column self_reported_ethnicity_ontology_term_id: na,na,na,na,na
#   First 5 elements of obs column sex: male,male,male,male,male
#   First 5 elements of obs column sex_ontology_term_id: PATO:0000384,PATO:0000384,PATO:0000384,PATO:0000384,PATO:0000384
#   First 5 elements of obs column suspension_type: nucleus,nucleus,nucleus,nucleus,nucleus
#   First 5 elements of obs column tissue: dorsolateral prefrontal cortex,dorsolateral prefrontal cortex,dorsolateral prefrontal cortex,dorsolateral prefrontal cortex,dorsolateral prefrontal cortex
#   First 5 elements of obs column tissue_ontology_term_id: UBERON:0009834,UBERON:0009834,UBERON:0009834,UBERON:0009834,UBERON:0009834
#   First 5 elements of obs column tissue_type: tissue,tissue,tissue,tissue,tissue
#   First 5 elements of obs column tissue_general: brain,brain,brain,brain,brain
#   First 5 elements of obs column tissue_general_ontology_term_id: UBERON:0000955,UBERON:0000955,UBERON:0000955,UBERON:0000955,UBERON:0000955
#   First 5 elements of obs column raw_sum: 3234.0,15374.0,3477.0,5919.0,2882.0
#   First 5 elements of obs column nnz: 1807,5297,1966,2932,1838
#   First 5 elements of obs column raw_mean_nnz: 1.7897066961815162,2.9023975835378515,1.7685656154628688,2.0187585266030013,1.5680087051142546
#   First 5 elements of obs column raw_variance_nnz: 6.361067854124572,32.20365172784915,8.65735234352957,11.58170190414085,3.0337500881114416
#   First 5 elements of obs column n_measured_vars: 23534,23534,23534,23534,23534
#   First 5 elements of var column soma_joinid: 0,1,2,3,4
#   First 5 elements of var column feature_id: ENSPTRG00000052463,ENSPTRG00000042737,ENSPTRG00000000799,ENSPTRG00000049634,ENSPTRG00000049400
#   First 5 elements of var column feature_name: ENSPTRG00000052463,ENSPTRG00000042737,HOOK1,RNF223,PRR9
#   First 5 elements of var column feature_type: protein_coding,protein_coding,protein_coding,protein_coding,protein_coding
#   First 5 elements of var column feature_length: 213,816,5839,723,351
#   First 5 elements of var column nnz: 615,38,48407,10,0
#   First 5 elements of var column n_measured_obs: 158099,158099,158099,158099,158099
# /home/ubuntu/miniconda3/envs/sc/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
# /home/ubuntu/miniconda3/envs/sc/lib/python3.11/functools.py:909: ImplicitModificationWarning: Transforming to str index.
#   return dispatch(args[0].__class__)(*args, **kw)
